# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
venue_df = pd.read_excel(r"C:\Users\jal32\Documents\NSS\Python\Data\Venue_LatLongs.xlsx", index_col=0)

venue_df['geometry'] = venue_df.apply(lambda x: Point((float(x.longitude), 
                                                         float(x.latitude))), 
                                        axis=1)

# %%
yelp_business = pd.read_json(r"C:\Users\jal32\Documents\NSS\Capstones\Data\yelp_business.json", lines=True)

# %%
yelp_business['geometry'] = yelp_business.apply(lambda x: Point((float(x.longitude), 
                                                         float(x.latitude))), 
                                        axis=1)

# %%
venue_geo = gpd.GeoDataFrame(venue_df, 
                           crs = 'EPSG:4326', 
                           geometry = venue_df['geometry'])

yelp_business_geo = gpd.GeoDataFrame(yelp_business, 
                           crs = 'EPSG:4326', 
                           geometry = yelp_business['geometry'])

# %%
tn_yelp_geo = yelp_business_geo.loc[yelp_business_geo.state == 'TN']

# %%
nash_yelp_geo = tn_yelp_geo.loc[tn_yelp_geo.city == 'Nashville']

# %%
filtered_tn_yelp_geo = nash_yelp_geo[nash_yelp_geo['categories'].notnull()]

# %%
nash_yelp_geo = filtered_tn_yelp_geo.loc[filtered_tn_yelp_geo['categories'].str.contains("restaurant|food|cocktail", case=False)]
nash_yelp_geo = nash_yelp_geo.loc[~filtered_tn_yelp_geo['categories'].str.contains("grocery|market|musicians|convenience", case=False)]
nash_yelp_geo
# Out:
#                    business_id                         name  \
# 9       bBDDEgkFA1Otx9Lfe7BZUQ               Sonic Drive-In
# 24      4iRzR7OaS-QaSXuvYxEGKA                    Super Dog
# 27      tMkwHmWFUEXrC9ZduonpTg           The Green Pheasant
# 47      lk9IwjZXqUMqqOhM774DtQ             Caviar & Bananas
# 89      oaboaRBUgGjbo2kfUIKDLQ             Mike's Ice Cream
# ...                        ...                          ...
# 150097  5quqExjLtFNhykec_na8pg     Bombay Palace Restaurant
# 150147  V-snSOHDO_mrWOBtJHtg4w               Domino's Pizza
# 150158  -KNgMklrxgRX2-T6xXeTZA                  Sal's Pizza
# 150277  n6W7Dtz5Xz4glh2bkEFX1Q            San Luis Taqueria
# 150322  2MAQeAqmD8enCT2ZYqUgIQ  The Melting Pot - Nashville
#
#                          address       city state postal_code   latitude  \
# 9            2312 Dickerson Pike  Nashville    TN       37207  36.208102
# 24          1160 Gallatin Pike S  Nashville    TN       37115  36.248570
# 27                 215 1st Ave S  Nashville    TN       37201  36.159886
# 47                 2031 Broadway  Nashville    TN       37203  36.148371
# 89                 129 2nd Ave N  Nashville    TN       37201  36.162649
# ...                          ...        ...   ...         ...        ...
# 150097            2912 W End Ave  Nashville    TN       37203  36.144508
# 150147       3041 Dickerson Pike  Nashville    TN       37207  36.228015
# 150158   710 Stewarts Ferry Pike  Nashville    TN       37214  36.153117
# 150277  1501 Lebanon Pike, Ste 2  Nashville    TN       37210  36.153582
# 150322      166 2nd Ave N, Ste A  Nashville    TN       37201  36.163875
#
#         longitude  stars  review_count  is_open  \
# 9      -86.768170    1.5            10        1
# 24     -86.719986    4.0             6        0
# 27     -86.773197    4.0           161        0
# 47     -86.798895    3.5           159        0
# 89     -86.775973    4.5           593        1
# ...           ...    ...           ...      ...
# 150097 -86.813787    4.0           476        1
# 150147 -86.758557    2.0            19        1
# 150158 -86.626122    3.5           150        1
# 150277 -86.721293    4.0             6        1
# 150322 -86.776311    4.0           204        0
#
#                                                attributes  \
# 9       {'RestaurantsAttire': ''casual'', 'Restaurants...
# 24      {'RestaurantsReservations': 'False', 'Restaura...
# 27      {'RestaurantsGoodForGroups': 'True', 'HappyHou...
# 47      {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 89      {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# ...                                                   ...
# 150097  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
# 150147  {'RestaurantsTakeOut': 'True', 'BusinessAccept...
# 150158  {'RestaurantsAttire': 'u'casual'', 'OutdoorSea...
# 150277  {'Alcohol': 'u'none'', 'WiFi': 'u'free'', 'Res...
# 150322  {'RestaurantsDelivery': 'False', 'RestaurantsR...
#
#                                                categories  \
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 24                                  Hot Dogs, Restaurants
# 27                         Restaurants, Japanese, Seafood
# 47      Coffee & Tea, Restaurants, Wine Bars, Bars, Ni...
# 89      Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
# ...                                                   ...
# 150097  Food, Indian, Pakistani, Chicken Shop, Seafood...
# 150147      Pizza, Restaurants, Sandwiches, Chicken Wings
# 150158          Italian, Salad, Restaurants, Pizza, Delis
# 150277                               Restaurants, Mexican
# 150322    Fondue, Beer, Wine & Spirits, Food, Restaurants
#
#                                                     hours  \
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 24                                                   None
# 27      {'Wednesday': '16:0-22:0', 'Thursday': '16:0-2...
# 47      {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...
# 89      {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
# ...                                                   ...
# 150097  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 150147  {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...
# 150158  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 150277  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...
# 150322  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
#
#                           geometry
# 9       POINT (-86.76817 36.20810)
# 24      POINT (-86.71999 36.24857)
# 27      POINT (-86.77320 36.15989)
# 47      POINT (-86.79889 36.14837)
# 89      POINT (-86.77597 36.16265)
# ...                            ...
# 150097  POINT (-86.81379 36.14451)
# 150147  POINT (-86.75856 36.22801)
# 150158  POINT (-86.62612 36.15312)
# 150277  POINT (-86.72129 36.15358)
# 150322  POINT (-86.77631 36.16388)
#
# [2833 rows x 15 columns]

# %%
# nash_yelp_geo.loc[nash_yelp_geo['longitude'].str.contains("-86.804558", case=False)]

# %%
nash_yelp_geo.plot();

# %%
# venue_geo.plot();

venue_geo
# Out:
#                        latitude  longitude  postal_code  \
# venue
# Ryman Auditorium      36.161247 -86.778471        37219
# Marathon Music Works  36.165150 -86.794296        37203
# The Basement          36.137220 -86.778590        37203
# The Basement East     36.175672 -86.755583        37206
# Mercy Lounge          36.153215 -86.780605        37203
# The 5 Spot            36.180017 -86.749982        37206
# The End               36.151420 -86.803875        37203
#
#                                         geometry
# venue
# Ryman Auditorium      POINT (-86.77847 36.16125)
# Marathon Music Works  POINT (-86.79430 36.16515)
# The Basement          POINT (-86.77859 36.13722)
# The Basement East     POINT (-86.75558 36.17567)
# Mercy Lounge          POINT (-86.78061 36.15322)
# The 5 Spot            POINT (-86.74998 36.18002)
# The End               POINT (-86.80387 36.15142)

# %%
nash_yelp_geo.geometry.centroid
# Out:
# C:\Users\jal32\AppData\Local\Temp\ipykernel_10748\2953407967.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   nash_yelp_geo.geometry.centroid
# 9         POINT (-86.76817 36.20810)
# 24        POINT (-86.71999 36.24857)
# 27        POINT (-86.77320 36.15989)
# 47        POINT (-86.79889 36.14837)
# 89        POINT (-86.77597 36.16265)
#                      ...
# 150097    POINT (-86.81379 36.14451)
# 150147    POINT (-86.75856 36.22801)
# 150158    POINT (-86.62612 36.15312)
# 150277    POINT (-86.72129 36.15358)
# 150322    POINT (-86.77631 36.16388)
# Length: 2833, dtype: geometry

# %%
center = nash_yelp_geo.geometry.centroid[150322]
print(center)
# Out:
# POINT (-86.77631100000001 36.1638754)
# C:\Users\jal32\AppData\Local\Temp\ipykernel_10748\3847661532.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = nash_yelp_geo.geometry.centroid[150322]

# %%
# reverse the order when constructing the array for folium location
area_center = [center.y, center.x]

# check the order of area_center, the location for our folium map
print(area_center)
# Out:
# [36.1638754, -86.776311]

# %%
#create our map of Nashville Zip Code 37207 and show it
map_nash_yelp = folium.Map(location =  area_center, zoom_start = 12)
map_nash_yelp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_855145949ef74f6ca7d2d3210c236fbc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_855145949ef74f6ca7d2d3210c236fbc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_855145949ef74f6ca7d2d3210c236fbc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_855145949ef74f6ca7d2d3210c236fbc%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.1638754%2C%20-86.776311%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import geopy.distance
dist_from_venue = []
for i, row in venue_df.iterrows():
    coords1 = (float(row['latitude']),float(row['longitude']))
    
    for j, row2 in nash_yelp_geo.iterrows():
        coords2 = (float(row2['latitude']),float(row2['longitude']))
        nash_yelp_geo.at[j, i] = geopy.distance.geodesic(coords1, coords2).miles
#         dist_from_venue.append(geopy.distance.geodesic(coords1, coords2).miles)
    
# nash_yelp_geo['dist_from_venue'] = dist_from_venue

# %%
venue_dist_df = pd.melt(nash_yelp_geo, id_vars=nash_yelp_geo.columns[:-7],
        var_name='venue', value_name='distance')

narrow_dist_df = venue_dist_df.loc[venue_dist_df['distance'] < .5]

narrow_dist_df
# Out:
#                   business_id                       name           address  \
# 2      tMkwHmWFUEXrC9ZduonpTg         The Green Pheasant     215 1st Ave S
# 4      oaboaRBUgGjbo2kfUIKDLQ           Mike's Ice Cream     129 2nd Ave N
# 5      X_E7U2lVNEwbH_gpOBmAHQ             Cerveza Jack's     135 2nd Ave N
# 9      42OM20QndpmsOSY6ccudBA  Union Teller Delicatessen      401 Union St
# 13     Gki1ureeRKqlIkQ-AELDVg                    Brugada   204 Commerce St
# ...                       ...                        ...               ...
# 19761  NvMN6SymLONl2N8zm-n4LA           Five Odd Fellows     1811 Broadway
# 19777  3YBUj9va9KbN1kkNcDQPug      Corner Pub at Midtown     2000 Broadway
# 19795  vysyK-G875gUP08n2Qnj3g         Music City Tippler  1922 Adelicia St
# 19809  ZLn-58uPlYBPfxj0x1tZkg                   Checkers    2000 W End Ave
# 19817  BhT3qX7-EndTIpSXgospBQ      Whiskey Rhythm Saloon  1811 Division St
#
#             city state postal_code   latitude  longitude  stars  review_count  \
# 2      Nashville    TN       37201  36.159886 -86.773197    4.0           161
# 4      Nashville    TN       37201  36.162649 -86.775973    4.5           593
# 5      Nashville    TN       37201  36.162799 -86.776016    4.0           182
# 9      Nashville    TN       37219  36.164800 -86.779929    3.5             6
# 13     Nashville    TN       37201  36.163323 -86.776592    3.5            49
# ...          ...   ...         ...        ...        ...    ...           ...
# 19761  Nashville    TN       37203  36.151228 -86.795893    3.0            31
# 19777  Nashville    TN       37203  36.149648 -86.798269    3.0            60
# 19795  Nashville    TN       37212  36.148331 -86.797742    3.5            64
# 19809  Nashville    TN       37203  36.151523 -86.799822    2.0            11
# 19817  Nashville    TN       37203  36.150410 -86.795415    3.5            41
#
#        is_open                                         attributes  \
# 2            0  {'RestaurantsGoodForGroups': 'True', 'HappyHou...
# 4            1  {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 5            1  {'GoodForDancing': 'True', 'Smoking': 'u'no'',...
# 9            0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 13           1  {'NoiseLevel': ''average'', 'Caters': 'False',...
# ...        ...                                                ...
# 19761        1  {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 19777        0  {'BusinessParking': '{'garage': False, 'street...
# 19795        0  {'HasTV': 'True', 'Ambience': '{'romantic': Fa...
# 19809        0  {'RestaurantsTakeOut': 'True', 'HasTV': 'False...
# 19817        0  {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
#
#                                               categories  \
# 2                         Restaurants, Japanese, Seafood
# 4      Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
# 5                  Nightlife, Restaurants, Bars, Mexican
# 9      Bagels, Restaurants, Caterers, Sandwiches, Eve...
# 13     Restaurants, Nightlife, Dance Clubs, Falafel, ...
# ...                                                  ...
# 19761                            Restaurants, Gastropubs
# 19777  Pubs, American (Traditional), Bars, Nightlife,...
# 19795  Arts & Entertainment, Music Venues, Bars, Loun...
# 19809                             Fast Food, Restaurants
# 19817  Bars, Burgers, Nightlife, Sports Bars, Sandwic...
#
#                                                    hours  \
# 2      {'Wednesday': '16:0-22:0', 'Thursday': '16:0-2...
# 4      {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
# 5      {'Monday': '0:0-0:0', 'Wednesday': '11:0-22:0'...
# 9      {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...
# 13     {'Monday': '17:0-2:30', 'Tuesday': '17:0-2:30'...
# ...                                                  ...
# 19761  {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...
# 19777  {'Monday': '11:0-1:0', 'Tuesday': '11:0-1:0', ...
# 19795  {'Tuesday': '17:0-1:0', 'Wednesday': '17:0-1:0...
# 19809                                               None
# 19817  {'Monday': '11:0-1:0', 'Tuesday': '11:0-2:0', ...
#
#                          geometry             venue  distance
# 2      POINT (-86.77320 36.15989)  Ryman Auditorium  0.309430
# 4      POINT (-86.77597 36.16265)  Ryman Auditorium  0.169848
# 5      POINT (-86.77602 36.16280)  Ryman Auditorium  0.174043
# 9      POINT (-86.77993 36.16480)  Ryman Auditorium  0.258182
# 13     POINT (-86.77659 36.16332)  Ryman Auditorium  0.177562
# ...                           ...               ...       ...
# 19761  POINT (-86.79589 36.15123)           The End  0.446541
# 19777  POINT (-86.79827 36.14965)           The End  0.336428
# 19795  POINT (-86.79774 36.14833)           The End  0.403724
# 19809  POINT (-86.79982 36.15152)           The End  0.226762
# 19817  POINT (-86.79542 36.15041)           The End  0.478161
#
# [992 rows x 17 columns]

# %%
map_nash_yelp = folium.Map(location =  area_center, zoom_start = 12)

#create a marker cluster
marker_cluster = MarkerCluster().add_to(map_nash_yelp)

# folium.GeoJson(polygon37207).add_to(cluster_map_37207)

# inside the loop add each marker to the cluster
for row_index, row_values in narrow_dist_df.iterrows():
    loc = [row_values['latitude'], row_values['longitude']]
    pop = str(row_values['name'])
    icon=folium.Icon(color="red",icon="star", prefix='fa')
    
    marker = folium.Marker(
        location = loc, 
        popup = pop,
    icon = icon) 
    
    marker.add_to(marker_cluster)

    
#save an interactive HTML map by calling .save()
# cluster_map_37207.save('../maps/cluster37207.html')

map_nash_yelp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e116e8f6fd9c402c94c5bb2c14d4b1ce%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e116e8f6fd9c402c94c5bb2c14d4b1ce%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A ...

# %%
narrow_dist_df.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\venue-distance.csv")

venue_geo.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\venue-geo.csv")

# %%
# test = narrow_dist_df.copy()
# test_0 = narrow_dist_df.copy()

# test

# %%
# e_dict = {"type_est":'venue',"name":"The End","geometry":venue_geo.loc['The End', "geometry"], 
#              "postal_code":venue_geo.loc['The End', "postal_code"],"latitude":venue_geo.loc['The End', "latitude"],
#              "longitude":venue_geo.loc['The End', "longitude"], "number":10}
             
# r_dict   = {"type_est":'venue',"name":"Ryman Auditorium","geometry":venue_geo.loc['Ryman Auditorium', "geometry"], 
#              "postal_code":venue_geo.loc['Ryman Auditorium', "postal_code"],"latitude":venue_geo.loc['Ryman Auditorium', "latitude"],
#              "longitude":venue_geo.loc['Ryman Auditorium', "longitude"], "number":10}
             
# m_dict = {"type_est":'venue',"name":"Marathon Music Works","geometry":venue_geo.loc['Marathon Music Works', "geometry"], 
#              "postal_code":venue_geo.loc['Marathon Music Works', "postal_code"],"latitude":venue_geo.loc['Marathon Music Works', "latitude"],
#              "longitude":venue_geo.loc['Marathon Music Works', "longitude"], "number":10}
             
# l_dict = {"type_est":'venue',"name":"Mercy Lounge","geometry":venue_geo.loc['Mercy Lounge', "geometry"], 
#              "postal_code":venue_geo.loc['Mercy Lounge', "postal_code"],"latitude":venue_geo.loc['Mercy Lounge', "latitude"],
#              "longitude":venue_geo.loc['Mercy Lounge', "longitude"], "number":10}
             
# b_dict = {"type_est":'venue',"name":"The Basement","geometry":venue_geo.loc['The Basement', "geometry"], 
#              "postal_code":venue_geo.loc['The Basement', "postal_code"],"latitude":venue_geo.loc['The Basement', "latitude"],
#              "longitude":venue_geo.loc['The Basement', "longitude"], "number":10}
             
# be_dict = {"type_est":'venue',"name":"The Basement East","geometry":venue_geo.loc['The Basement East', "geometry"], 
#              "postal_code":venue_geo.loc['The Basement East', "postal_code"],"latitude":venue_geo.loc['The Basement East', "latitude"],
#              "longitude":venue_geo.loc['The Basement East', "longitude"], "number":10}
            
# s_dict = {"type_est":'venue',"name":"The 5 Spot","geometry":venue_geo.loc['The 5 Spot', "geometry"], 
#              "postal_code":venue_geo.loc['The 5 Spot', "postal_code"],"latitude":venue_geo.loc['The 5 Spot', "latitude"],
#              "longitude":venue_geo.loc['The 5 Spot', "longitude"], "number":10}
# test_dict

# test['type_est'] = "food"

# test['number'] = 0

# %%
# test2 = test.append([e_dict, r_dict, m_dict, l_dict, b_dict, be_dict, s_dict], ignore_index=False)
# test2

# %%
# narrow_dist_df = test2

narrow_dist_df.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\venue-distance.csv")

# %%
# narrow_dist_df
