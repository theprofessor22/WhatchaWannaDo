# %%
import requests
from bs4 import BeautifulSoup as BS
import re
import pandas as pd
from datetime import date

# %% [markdown]
# # EXIT/IN

# %%
# Exit_URL = 'https://exitin.com/calendar/'
# headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'} 
# response = requests.get(Exit_URL, headers=headers)
# exit_webpage = BS(response.content, 'lxml')

# exit_calendar = exit_webpage.find("div", attrs= {"class":"calendar"})
# exit_urls = exit_calendar.find_all("a")
# exit_url_list = []
# for url in exit_urls:
#     if url['href'] not in exit_url_list:
#         exit_url_list.append(url['href'])
# exit_url_list
    

    
# i = 0
# exit_events_list = []
# for exit_url in exit_url_list:
#     if exit_url != None:
# #         print(exit_url)
#         exit_dict = {}
#     #     price3 = "Event Sold Out."
#         exit_ticket_response = requests.get(exit_url, headers=headers)
#         exit_ticket_webpage = BS(exit_ticket_response.content, 'lxml')
# #         print(exit_ticket_webpage)
#         exit_list_date = exit_ticket_webpage.find('h3', attrs= {"class":"event-h3"})
# #         print(exit_list_date)
#         exit_list_artist = exit_ticket_webpage.find('div', attrs= {"class":"tw-name"})
#         exit_list_time = exit_ticket_webpage.find('span', attrs= {"class":"tw-event-time"})
#         exit_list_price = exit_ticket_webpage.find('div', attrs= {"class":"tw-price"})
        
#         if exit_list_date != None:
#             exit_dict['event_date'] = exit_list_date.text
#         else:
#             exit_dict['event_date'] = "Date Not Found"
            
#         if exit_list_artist != None:
#             exit_dict['event_name'] = exit_list_artist.text.strip()
#         else:
#             exit_dict['event_name'] = "Artist Not Found"
            
#         if exit_list_time != None:
#             exit_dict['show_time'] = exit_list_time.text
#         else:
#             exit_dict['show_time'] = "Time Not Found"
        
#         if exit_list_price != None:
#             exit_dict['price'] = exit_list_price.text
#         else:
#             exit_dict['price'] = "Price Not Found"
#         exit_events_list.append(exit_dict)
#         i += 1  
#         if i == 20:
#             break
    

# exit_calendar = webpage.find('div', attrs={'class' : 'calendar'})
# exit_month = webpage.find('table', attrs= {'class' : 'calendar'})
# exit_list_date = exit_month.find_all("div", class_="detail detail_event_date")
# month_events = exit_month.findAll('div', attrs= {'class' : 'calendar'})

# %%
# exit_times = []

# for entry in month_events:
#     exit_times.append(entry.find('div', attrs= {'class' : 'detail detail_time'}).get_text())

# exit_times = pd.DataFrame(exit_times)
# exit_times.columns =['Time']
# exit_times
# exit_times['Time'] = exit_times.Time.str.replace('Event Time', '')

# %%
# exit_artist = []

# for artist in exit_month.find_all('h1'):
#         exit_artist.append(artist.text)

# %%
# exit_ticket_url = webpage.find_all('a', attrs= {'class' : 'event_tickets'})
# exit_ticket_url

# i = 0
# exit_prices_list = []

# for url in exit_ticket_url:
#     exit_dict = {}
#     price1 = "Event Sold Out."
#     ticket_response = requests.get(url['href'])
#     ticket_webpage = BS(ticket_response.content, 'lxml')
#     list_price = ticket_webpage.find('div', class_='price column p-t-7 float-l')
#     if list_price is not None:
#         exit_price = list_price.find('span', class_='float-l')
#         print(exit_price)
#         price1 = exit_price.text
#     exit_dict['event_date'] = exit_list_date[i].text.replace("Event Date","")
#     exit_dict['event_name'] = exit_artist[i]
#     exit_dict['show_time'] = exit_times[i]
#     exit_dict['price'] = price1
#     exit_prices_list.append(exit_dict)
#     i += 1  
#     if i == 1:
#         break

# %%
# exit_event_df = pd.DataFrame.from_dict(exit_prices_list)

# %%
# exit_event_df['show_time'] = exit_event_df['show_time'].map(lambda x: x.lstrip('Event Time'))
# exit_event_df

# %% [markdown]
# # MARATHON

# %%
MMW_URL = 'https://www.marathonmusicworks.com/tickets-2/'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'} 
mmw_response = requests.get(MMW_URL, headers=headers)
mmw_webpage = BS(mmw_response.content, 'lxml')

# %%
mmw_calendar = mmw_webpage.find_all('div', attrs={'class' : 'container'})
mmw_calendar_urls = mmw_calendar[0].find_all('a')

mmw_url_list = []
for url in mmw_calendar_urls:
    str_url = str(url)
    mmw_url_list.append(re.search('="(.*)">', str_url).group(1))
mmw_url_list = mmw_url_list[::3]
# print(mmw_url_list)


i = 0
mmw_prices_list = []
for mmw_url in mmw_url_list:
    mmw_dict = {}
    price2 = "Event Sold Out."
    mmw_ticket_response = requests.get(mmw_url, headers=headers)
    mmw_ticket_webpage = BS(mmw_ticket_response.content, 'lxml')
    mmw_list_date = mmw_ticket_webpage.find('time',attrs= {'class' : 'date-time'})
    if mmw_list_date != None:
        
#     print(mmw_list_date)
#     mmw_list_date = re.sub(r'[\w{3}\s\d{2},\s\d{4}]',"", str(mmw_list_date))
        mmw_list_date = re.search('\w{3}\s\d{2},\s\d{4}', str(mmw_list_date)).group(0)
#         print(mmw_list_date)
        mmw_list_artist = mmw_ticket_webpage.find('h1',attrs= {'class' : 'event-name headliners'})
        mmw_list_time = mmw_ticket_webpage.find('span',attrs= {'class' : 'start'})
        mmw_list_price = mmw_ticket_webpage.find('span',attrs= {'class' : 'price-range'})
        mmw_dict['event_date'] = mmw_list_date
        mmw_dict['event_name'] = mmw_list_artist.text
        mmw_dict['show_time'] = mmw_list_time.text.strip()
        mmw_dict['price'] = mmw_list_price.text
        mmw_dict['ticket_url'] = mmw_url
        mmw_prices_list.append(mmw_dict)
        i += 1  
        if i == 21:
            break

# %%
mmw_df = pd.DataFrame.from_dict(mmw_prices_list)
mmw_df['price'] = mmw_df['price'].str.replace("$","")
mmw_df['Venue'] = 'Marathon Music Works'
mmw_df['show_time'] = mmw_df.show_time.str.replace(" pm","")

mmw_df
# Out:
# <ipython-input-33-601f1ebe30b2>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   mmw_df['price'] = mmw_df['price'].str.replace("$","")
#       event_date                                        event_name show_time  \
# 0   May 04, 2022    SNOH AALEGRA - UGH. THESE TEMPORARY HIGHS TOUR     08:00
# 1   May 07, 2022                               Emo Night Nashville     08:00
# 2   May 10, 2022                                     Stick Figure      08:30
# 3   May 11, 2022                                      Still Woozy      08:00
# 4   May 13, 2022                                        Dean Lewis     08:00
# 5   May 14, 2022                                         Aly & AJ      08:00
# 6   May 19, 2022             Alexisonfire (Moved to Brooklyn Bowl)     08:00
# 7   May 22, 2022       Sum 41 & Simple Plan: The Blame Canada Tour     07:00
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'} 
base_response = requests.get(base_URL, headers=headers)
base_webpage = BS(base_response.content, 'lxml')
base_list = base_webpage.find_all("div", attrs= {"class":"tw-info-price-buy-tix"})
base_list

base_url_list = []
for item in base_list:
    href_sec = item.find_all('a')
    if len(href_sec) > 1:
        base_url_list.append(href_sec[-1]['href'])



# base_url_list = []
# for url in base_list:
#     str_url = str(url)
#     base_url_list.append(re.search('href="(.*)">', str_url).group(1))
# base_url_list

i = 0
base_events_list = []
for base_url in base_url_list:
    if base_url != None:
#         print(base_url)
        base_dict = {}
    #     price3 = "Event Sold Out."
        base_ticket_response = requests.get(base_url, headers=headers)
        base_ticket_webpage = BS(base_ticket_response.content, 'lxml')
        base_list_date = base_ticket_webpage.find('span', attrs= {"class":"tw-event-date"})
        base_list_artist = base_ticket_webpage.find('div', attrs= {"class":"tw-name"})
        base_list_time = base_ticket_webpage.find('span', attrs= {"class":"tw-event-time"})
        base_list_price = base_ticket_webpage.find('div', attrs= {"class":"tw-price"})
        
        if base_list_date != None:
            base_dict['event_date'] = base_list_date.text
        else:
            base_dict['event_date'] = "Date Not Found"
            
        if base_list_artist != None:
            base_dict['event_name'] = base_list_artist.text.strip()
        else:
            base_dict['event_name'] = "Artist Not Found"
            
        if base_list_time != None:
            base_dict['show_time'] = base_list_time.text
        else:
            base_dict['show_time'] = "Time Not Found"
        
        if base_list_price != None:
            base_dict['price'] = base_list_price.text.strip()
        else:
            base_dict['price'] = "Price Not Found"
        base_dict['ticket_url'] = base_url
        base_events_list.append(base_dict)
        i += 1  
        if i == 50:
            break

# %%
base_df = pd.DataFrame.from_dict(base_events_list)
base_df['Venue'] = 'The Basement'
base_df['price'] = base_df['price'].str.replace("/"," | ")
base_df['price'] = base_df['price'].str.replace("DOS|day of show","Day of Show")
base_df['show_time'] = base_df.show_time.str.replace(" pm","")
# base_df['price'] = base_df['price'].str.replace("?:𝐴𝐷𝑉","")
base_df
# Out:
# <ipython-input-38-2966fbde914b>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   base_df['price'] = base_df['price'].str.replace("DOS|day of show","Day of Show")
#         event_date                                         event_name  \
# 0   April 22, 2022                       Penny & Sparrow w/ Lera Lynn
# 1   April 22, 2022                  *repeat repeat w/ The Sewing Club
# 2   April 23, 2022                Government Cheese - World Tour 2022
# 3   April 23, 2022                       *repeat repeat w/ BadCulture
# 4   April 24, 2022  Nashville Tour Stop: feat. Lake & Lyndale, Nov...
# 5   April 24, 2022               The Lil Smokies w/ Michigan Rattlers
# 6   April 25, 2022  Blac Rabbit - "Interstellar" Album Release Tou...
# 7   April 25, 2022              FEELRS, The Weird Sisters, The Reveal
# 8   April 25, 2022                                          The Slaps
# 9   April 26, 2022                                                GFM
# 10  April 26, 2022  New Faces Night feat. Amanda Stewart, Krash Ka...
# 11  April 26, 2022                           Son Volt w/ S.G. Goodman
# 12  April 27, 2022                         Helado Negro w/ Dream Wave
# 13  April 27, 2022            Dallas Ugly, Maya De Vitry, Jobi Riccio
# 30  https://www.thebasementnashville.com/event/116...  The Basement
# 31  https://www.thebasementnashville.com/event/115...  The Basement
# 32  https://www.thebasementnashville.com/event/120...  The Basement
# 33  https://www.thebasementnashville.com/event/120...  The Basement
# 34  https://www.thebasementnashville.com/event/113...  The Basement
# 35  https://www.thebasementnashville.com/event/120...  The Basement
# 36  https://www.thebasementnashville.com/event/118...  The Basement
# 37  https://www.thebasementnashville.com/event/118...  The Basement
# 38  https://www.thebasementnashville.com/event/119...  The Basement
# 39  https://www.thebasementnashville.com/event/116...  The Basement
# 40  https://www.thebasementnashville.com/event/118...  The Basement
# 41  https://www.thebasementnashville.com/event/120...  The Basement
# 42  https://www.thebasementnashville.com/event/116...  The Basement
# 43  https://www.thebasementnashville.com/event/116...  The Basement
# 44  https://www.thebasementnashville.com/event/118...  The Basement
# 45  https://www.thebasementnashville.com/event/117...  The Basement
# 46  https://www.thebasementnashville.com/event/117...  The Basement
# 47  https://www.thebasementnashville.com/event/118...  The Basement
# 48  https://www.thebasementnashville.com/event/114...  The Basement
# 49  https://www.thebasementnashville.com/event/119...  The Basement

# %%
base_df.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\base_df.csv")

# %% [markdown]
# # THE BASEMENT EAST

# %%
beast_URL = 'https://www.thebasementnashville.com/basement-east-calendar/'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'} 
beast_response = requests.get(beast_URL, headers=headers)
beast_webpage = BS(beast_response.content, 'lxml')


beast_list = beast_webpage.find_all("div", attrs= {"class":"tw-info-price-buy-tix"})
beast_url_list = []
for item in beast_list:
    href_sec = item.find_all('a')
    if len(href_sec) > 1:
        beast_url_list.append(href_sec [-1]['href'])
    
i = 0
beast_events_list = []
for beast_url in beast_url_list:
    if beast_url != None:
#         print(base_url)
        beast_dict = {}
    #     price3 = "Event Sold Out."
        beast_ticket_response = requests.get(beast_url, headers=headers)
        beast_ticket_webpage = BS(beast_ticket_response.content, 'lxml')
        beast_list_date = beast_ticket_webpage.find('span', attrs= {"class":"tw-event-date"})
        beast_list_artist = beast_ticket_webpage.find('div', attrs= {"class":"tw-name"})
        beast_list_time = beast_ticket_webpage.find('span', attrs= {"class":"tw-event-time"})
        beast_list_price = beast_ticket_webpage.find('div', attrs= {"class":"tw-price"})
            
        if beast_list_date != None:
            beast_dict['event_date'] = beast_list_date.text
        else:
            beast_dict['event_date'] = beast_list_date2
            
        if beast_list_artist != None:
            beast_dict['event_name'] = beast_list_artist.text.strip()
        else:
            beast_dict['event_name'] = "Artist Not Found"
            
        if beast_list_time != None:
            beast_dict['show_time'] = beast_list_time.text
        else:
            beast_dict['show_time'] = "Time Not Found"
        
        if beast_list_price != None:
            beast_dict['price'] = beast_list_price.text.strip()
        else:
            beast_dict['price'] = "Price Not Found"        
        beast_dict['ticket_url'] = beast_url
        beast_events_list.append(beast_dict)
        i += 1  
        if i == 50:
            break

# %%
beast_df = pd.DataFrame.from_dict(beast_events_list)
beast_df['price'] = beast_df['price'].str.replace("$","")
beast_df['price'] = beast_df['price'].str.replace("/"," | ")
beast_df['price'] = beast_df['price'].str.replace("DOS|day of show","Day of Show")
beast_df['show_time'] = beast_df.show_time.str.replace(" pm","")
beast_df['Venue'] = 'The Basement East'

beast_df
# Out:
# <ipython-input-41-e07e85799d7b>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# 39    June 9, 2022                                 The Emo Night Tour
# 40   June 10, 2022  NEWLY RESCHEDULED DATE: The Shadowboxers w/ Sh...
# 41   June 12, 2022                       SOLD OUT! Goth Babe w/ Miloe
# 42   June 13, 2022                                Ann Wilson of Heart
# 43   June 14, 2022                                Ann Wilson of Heart
# 44   June 15, 2022                               Wet w/ Hannah Jadagu
# 45   June 17, 2022                                                QDP
# 46   June 21, 2022                               Hinder w/ No Resolve
# 47   June 22, 2022       Penelope Scott w/ Fanclubwallet and Yot Club
# 48   June 23, 2022                                           Erin Rae
# 49   June 24, 2022                    Ocean Alley: North America 2022
#
#    show_time                                  price  \
# 0       8:00   22 ADV  |  25 Day of Show  |  79 VIP
# 1       8:00                                     20
# 2       8:00              17 ADV  |  20 Day of Show
# 3       8:00              12 ADV  |  15 Day of Show
# 4       8:00              22 ADV  |  25 Day of Show
# 5       8:00              16 ADV  |  18 Day of Show
# 6       8:00              20 ADV  |  23 Day of Show
# 7       8:00              45 ADV  |  50 Day of Show
# 8       8:00              20 ADV  |  25 Day of Show
# 9       8:00                                  25.00
# 10      8:00              17 ADV  |  20 Day of Show
# 11      8:00  25 ADV  |  28 Day of Show  |  125 VIP
# 12      8:00              27 ADV  |  30 Day of Show
# 13      8:00              23 ADV  |  25 Day of Show
# 14      8:00           23.50 ADV  |  28 Day of Show
# 15      9:00                                  12-25
# 16      8:00              17 ADV  |  20 Day of Show
# 17      8:00                                  30.00
# 18      8:00           23.50 ADV  |  27 Day of Show
# 19      8:00              20 ADV  |  25 Day of Show
# 20      9:00                                  20.00
# 21      8:00                                  20.00
# 22      7:30              25 ADV  |  30 Day of Show
# 23      8:00              30 ADV  |  35 Day of Show
# 24      8:00              16 ADV  |  18 Day of Show
# 25      8:00              22 ADV  |  25 Day of Show
# 26      9:00                    1 Cover at the door
# 27      8:00              20 ADV  |  22 Day of Show
# 28      8:00              15 ADV  |  20 Day of Show
# 29      7:30                                  26.00
# 30      8:00              25 ADV  |  30 Day of Show
# 31      8:00                                  20.00
# 32      8:00              15 ADV  |  18 Day of Show
# 33      8:00              25 ADV  |  30 Day of Show
# 34      8:00                                     25
# 35      8:00              16 ADV  |  20 Day of Show
# 36      8:00                                  20-85
# 37      8:00              18 ADV  |  21 Day of Show
# 38      8:00                                  18.00
# 39      8:00                                  15.00
# 40      8:00                                  20.00
# 41      8:00                          22.00 - 97.00
# 42      8:00              42 ADV  |  45 Day of Show
# 43      8:00              42 ADV  |  45 Day of Show
# 44      8:00              22 ADV  |  25 Day of Show
# 45      9:00                    1 Cover at the door
# 46      7:30              22 ADV  |  25 Day of Show
# 47      8:00              18 ADV  |  20 Day of Show
# 48      8:00              18 ADV  |  20 Day of Show
# 49      8:00              18 ADV  |  20 Day of Show
#
#                                            ticket_url              Venue
# 0   https://www.thebasementnashville.com/event/114...  The Basement East
# 1   https://www.thebasementnashville.com/event/115...  The Basement East
# 2   https://www.thebasementnashville.com/event/117...  The Basement East
# 3   https://www.thebasementnashville.com/event/118...  The Basement East
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'} 
mrcy_response = requests.get(mrcy_URL, headers=headers)
mrcy_webpage = BS(mrcy_response.content, 'lxml') 
a_list = mrcy_webpage.find_all("a")
a_list

mrcy_url_list = []
for a in a_list[14:]:
    mrcy_url_list.append(a['href'])

mrcy_url_list = mrcy_url_list[::3]
mrcy_urls = []
for url in mrcy_url_list:
    url = url.replace("eventbrite","mercylounge")
    url = url.replace("tickets-","")
    url = url.replace("#tickets","/")
    mrcy_urls.append(url)

mrcy_urls
i = 0
mrcy_events_list = []
for mrcy_url in mrcy_urls:
    if mrcy_url != None:
#         print(mrcy_url)
        mrcy_dict = {}
        price3 = "Price Not Listed"
        mrcy_ticket_response = requests.get(mrcy_url, headers=headers)
        mrcy_ticket_webpage = BS(mrcy_ticket_response.content, 'lxml')
        mrcy_list_date = mrcy_ticket_webpage.find('span', attrs= {"class":"dates"})
        mrcy_list_artist = mrcy_ticket_webpage.find('h1', attrs= {"class":"event-name headliners"})
        mrcy_list_time = mrcy_ticket_webpage.find('span', attrs= {"class":"start"})
        mrcy_list_price = mrcy_ticket_webpage.find('span', attrs= {"class":"price-range"})
        mrcy_dict['event_date'] = mrcy_list_date.text
        mrcy_dict['event_name'] = mrcy_list_artist.text
        mrcy_dict['show_time'] = mrcy_list_time.text
        if mrcy_list_price != None:
            mrcy_dict['price'] = mrcy_list_price.text
        else:
            mrcy_dict['price'] = price3  
        mrcy_dict['ticket_url'] = mrcy_url
        mrcy_events_list.append(mrcy_dict)
        i += 1  
        if i == 30:
            break

# %%
mrcy_df = pd.DataFrame.from_dict(mrcy_events_list)
# beast_df['price'] = beast_df['price'].str.replace("$","\$")
mrcy_df

mrcy_df['event_date'] = mrcy_df.event_date.str.replace(".*(·)","")
mrcy_df['show_time'] = mrcy_df.show_time.str.replace("Show: ","")
mrcy_df['show_time'] = mrcy_df.show_time.str.replace(" PM",":00")

mrcy_df['Venue'] = 'Mercy Lounge'
mrcy_df
# Out:
# <ipython-input-44-b7e8614cb215>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   mrcy_df['event_date'] = mrcy_df.event_date.str.replace(".*(·)","")
#          event_date                                         event_name  \
# 0    April 22, 2022                Jessica Lea Mayfield w/ W.B. Wooten
# 1    April 22, 2022    My So-Called Band: The Ultimate 90s Experience!
# 2    April 23, 2022                                   Guilty Pleasures
# 3    April 24, 2022                              Luna Luna & Dreamgirl
# 4    April 25, 2022                              HOMESHAKE w/ duendita
# 5    April 26, 2022        The Felice Brothers w/ Joshua Black Wilkins
# 6    April 27, 2022                            LVRBOY w/ Savanna Leigh
# 7    April 28, 2022               The Talbott Brothers w/ Evan Bartels
# 8    April 29, 2022        Tristen w/ The Prescriptions & Abby Johnson
# 9    April 29, 2022          Dan Andriano & The Bygones w/ Emily Wolfe
# 10   April 30, 2022                                   The Story So Far
# 11   April 30, 2022                                Destroyer w/ Rosali
# 12      May 1, 2022                                       Kevin Devine
# 13      May 2, 2022                                            Allie X
# 14      May 2, 2022  Bonnie ‘Prince’ Billy & Matt Sweeney “Superwol...
# 15      May 5, 2022            James Arthur: It’ll All Make Sense Tour
# 16      May 5, 2022           Gavin DeGraw: Full Circle Tour - Night 1
# 17      May 6, 2022           Gavin DeGraw: Full Circle Tour - Night 2
# 17  https://www.mercylounge.com/e/gavin-degraw-ful...  Mercy Lounge
# 18  https://www.mercylounge.com/e/swift-and-sour-a...  Mercy Lounge
# 19  https://www.mercylounge.com/e/supersonic-north...  Mercy Lounge
# 20  https://www.mercylounge.com/e/the-hu-w-the-hau...  Mercy Lounge
# 21  https://www.mercylounge.com/e/all-that-remains...  Mercy Lounge
# 22  https://www.mercylounge.com/e/born-ruffians-ju...  Mercy Lounge
# 23  https://www.mercylounge.com/e/boulet-brothers-...  Mercy Lounge
# 24  https://www.mercylounge.com/e/the-palms-289881...  Mercy Lounge
# 25  https://www.mercylounge.com/e/notelle-nyctophi...  Mercy Lounge
# 26  https://www.mercylounge.com/e/the-foxies-w-lom...  Mercy Lounge
# 27  https://www.mercylounge.com/e/allan-rayman-921...  Mercy Lounge
# 28  https://www.mercylounge.com/e/the-ghost-of-pau...  Mercy Lounge
# 29  https://www.mercylounge.com/e/the-weeks-w-betc...  Mercy Lounge

# %%
mrcy_df.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\mrcy_df.csv")

# %% [markdown]
# # Ryman

# %%
rymn_URL = 'https://ryman.com/events/'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'} 
rymn_response = requests.get(rymn_URL, headers=headers)
rymn_webpage = BS(rymn_response.content, 'lxml') 

rymn_narrow = rymn_webpage.find_all("a")
rymn_narrow
rymn_url_list = []
for a in rymn_narrow[48:]:
    if "ryman.com/event" in a['href']:
        rymn_url_list.append(a['href'])
    
rymn_url_list
rymn_url_list = list(pd.Series(rymn_url_list).unique())

i = 0
rymn_events_list = []
for rymn_url in rymn_url_list:
    if rymn_url != None:
#         print(mrcy_url)
        rymn_dict = {}
        price3 = "Price Not Listed"
        rymn_ticket_response = requests.get(rymn_url, headers=headers)
        rymn_ticket_webpage = BS(rymn_ticket_response.content, 'lxml')
        rymn_list_date = rymn_ticket_webpage.find('div', attrs= {"class":"start-time"})
        rymn_list_date1 = re.search('(\w*\s\d*,\s\d{4})', str(rymn_list_date)).group(0)
        rymn_list_artist = rymn_ticket_webpage.find('h1', attrs= {"class":"concert"})
        rymn_list_time = re.search('\s(\d.\d+\s\w\w\s)CDT', str(rymn_list_date)).group(0)
        rymn_list_price = rymn_ticket_webpage.find('p', attrs= {"class":"theprices"})
        rymn_dict['event_date'] = rymn_list_date1
        rymn_dict['event_name'] = rymn_list_artist.text
        rymn_dict['show_time'] = rymn_list_time.replace("CDT","").strip()
        if rymn_list_price != None:
            rymn_dict['price'] = rymn_list_price.text.strip()
        else:
            rymn_dict['price'] = price3  
        rymn_dict['ticket_url'] = rymn_url
        rymn_events_list.append(rymn_dict)
        i += 1  
        if i == 14:
            break

# %%
rymn_df = pd.DataFrame.from_dict(rymn_events_list)
rymn_df['Venue'] = 'Ryman Auditorium'

rymn_df['show_time'] = rymn_df.show_time.str.replace(" PM","")

rymn_df
# Out:
#         event_date                   event_name show_time  \
# 0   April 22, 2022           Spring Plaza Party      5:00
# 1   April 22, 2022               Bert Kreischer      7:00
# 2   April 22, 2022               Bert Kreischer      9:30
# 3   April 23, 2022             Taylor Tomlinson      7:00
# 4   April 24, 2022                 Nikki Glaser      7:00
# 5   April 24, 2022            The 85 South Show      8:00
# 6   April 25, 2022                Gladys Knight      7:30
# 7   April 28, 2022          Jessie James Decker      7:30
# 8   April 29, 2022           Spring Plaza Party      6:00
# 9   April 29, 2022                 Walker Hayes      8:00
# 10  April 30, 2022          Trampled By Turtles      8:00
# 11     May 1, 2022  Kurt Vile and The Violators      7:30
# 12     May 3, 2022                 Van Morrison      7:30
# 13     May 4, 2022                 Van Morrison      7:30
#
#                                   price  \
# 0           Free and Open to the Public
# 1                       $59.75 / $39.75
# 2                       $59.75 / $39.75
# 3                       $49.75 / $39.75
# 4             $159.68 / $39.50 / $29.50
# 5                $155 / $75 / $55 / $40
# 6              $89.50 / $79.50 / $69.50
# 7                       $60 / $40 / $30
# 8           Free and Open to the Public
# 9                       $50 / $30 / $25
# 10                         $50 / $39.50
# 11                      $48 / $38 / $33
# 12  $149.50 / $129.50 / $99.50 / $59.50
# 13  $149.50 / $129.50 / $99.50 / $59.50
#
#                                            ticket_url             Venue
# 0   https://ryman.com/event/spring-plaza-party-042...  Ryman Auditorium
# 1             https://ryman.com/event/bert-kreischer/  Ryman Auditorium
# 2        https://ryman.com/event/bert-kreischer-late/  Ryman Auditorium
# 3           https://ryman.com/event/taylor-tomlinson/  Ryman Auditorium
# 4       https://ryman.com/event/nikki-glaser-042422e/  Ryman Auditorium
# 5                   https://ryman.com/event/85-south/  Ryman Auditorium
# 6       https://ryman.com/event/gladys-knight-042522/  Ryman Auditorium
# 7        https://ryman.com/event/jessie-james-decker/  Ryman Auditorium
# 8   https://ryman.com/event/spring-plaza-party-042...  Ryman Auditorium
# 9               https://ryman.com/event/walker-hayes/  Ryman Auditorium
# 10  https://ryman.com/event/trampled-by-turtles-04...  Ryman Auditorium
# 11                 https://ryman.com/event/kurt-vile/  Ryman Auditorium
# 12       https://ryman.com/event/van-morrison-050322/  Ryman Auditorium
# 13       https://ryman.com/event/van-morrison-050422/  Ryman Auditorium

# %%
rymn_df.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\rymn_df.csv")

# %% [markdown]
# # The 5 Spot

# %%
spot_URL = 'https://the5spot.club/'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'} 
spot_response = requests.get(spot_URL, headers=headers)
spot_webpage = BS(spot_response.content, 'lxml') 

spot_narrow = spot_webpage.find("div", attrs= {"class":"tribe-events-calendar-month"})

for div in spot_narrow.find_all("div", {'class':'tribe-events-calendar-month__day tribe-events-calendar-month__day--past'}): 
    div.decompose()

spot_narrow = spot_narrow.find_all('a')
    
spot_narrow

spot_url_list = []
for a in spot_narrow:
    if ".club/event/" in a['href'] and '/all/' not in a['href']:
        if a['href'] not in spot_url_list:
            spot_url_list.append(a['href'])
        
spot_url_list

i = 0
spot_events_list = []
for spot_url in spot_url_list:
    if spot_url != None:
#         print(base_url)
        spot_dict = {}
    #     price3 = "Event Sold Out."
        spot_ticket_response = requests.get(spot_url, headers=headers)
        spot_ticket_webpage = BS(spot_ticket_response.content, 'lxml')
        spot_list_date = spot_ticket_webpage.find('span', attrs= {"class":"tribe-event-date-start"})
        spot_list_date1 = re.search('>(.*)@', str(spot_list_date)).group(1).strip()
        spot_list_artist = spot_ticket_webpage.find('h1', attrs= {"class":"tribe-events-single-event-title"})
        spot_list_time = re.search('@\s(.*)<', str(spot_list_date)).group(1).strip()
        spot_list_price = spot_ticket_webpage.find('span', attrs= {"class":"tribe-events-cost"})
            
        if spot_list_date != None:
            spot_dict['event_date'] = spot_list_date1
        else:
            spot_dict['event_date'] = "No Date Listed"
            
        if spot_list_artist != None:
            spot_dict['event_name'] = spot_list_artist.text.strip()
        else:
            spot_dict['event_name'] = "Artist Not Found"
            
        if spot_list_time != None:
            spot_dict['show_time'] = spot_list_time
        else:
            spot_dict['show_time'] = "Time Not Found"
        
        if spot_list_price != None:
            spot_dict['price'] = spot_list_price.text
        else:
            spot_dict['price'] = "$10"
        spot_dict['ticket_url'] = spot_url
        spot_events_list.append(spot_dict)
        i += 1  
        if i == 40:
            break

# %%
spot_df = pd.DataFrame.from_dict(spot_events_list)
spot_df['Venue'] = 'The 5 Spot'
spot_df['show_time'] = spot_df.show_time.str.replace(" pm","")
spot_df
# Out:
#    event_date                                         event_name show_time  \
# 0    April 22         Jax Hollow, Taylor Sackson, Sleeper Signal      9:00
# 1    April 22             Tim Carroll Rock’n’Roll Happy Hour !!!      6:00
# 2    April 23                                      PRIVATE PARTY      5:00
# 3    April 24                                “Sunday Night Soul”      6:00
# 4    April 25                   Blue Monday with The Tiger Beats      6:00
# 5    April 25                          MOTOWN MONDAY dance party      9:00
# 6    April 26                           $5 DeadBeats Tie Dye Jam      6:00
# 7    April 26                    Two Dollar Tues with Derek Hoke      8:00
# 8    April 27                                         Chuck Mead      6:00
# 9    April 27  Swill TV: Hans Condor, The Bomb bards, and The...      9:00
# 10   April 28                                     Jack Silverman      6:00
# 11   April 28  Sleeper Signal, Dylan Taylor & Hippie Speedbal...      9:00
# 12   April 29      Megg Farrell, Ashley Campbell, Hannah Juanita      9:00
# 13   April 29             Tim Carroll Rock’n’Roll Happy Hour !!!      6:00
# 14   April 30                                        Hoedown VII      4:00
#
#    price                                         ticket_url       Venue
# 0    $10          https://the5spot.club/event/jax-hollow-2/  The 5 Spot
# 1    $10  https://the5spot.club/event/tim-carroll-rocknr...  The 5 Spot
# 2    $10         https://the5spot.club/event/private-party/  The 5 Spot
# 3    $10  https://the5spot.club/event/sunday-night-soul-12/  The 5 Spot
# 4     $5  https://the5spot.club/event/blue-monday-with-t...  The 5 Spot
# 5     $5  https://the5spot.club/event/motown-monday-danc...  The 5 Spot
# 6    $10  https://the5spot.club/event/deadbeats-tie-dye-...  The 5 Spot
# 7     $2  https://the5spot.club/event/two-dollar-tues-wi...  The 5 Spot
# 8    $10          https://the5spot.club/event/chuck-mead-3/  The 5 Spot
# 9    $10  https://the5spot.club/event/swill-tv-hans-cond...  The 5 Spot
# 10   $10      https://the5spot.club/event/jack-silverman-2/  The 5 Spot
# 11   $10  https://the5spot.club/event/sleeper-signal-dyl...  The 5 Spot
# 12   $10  https://the5spot.club/event/megg-farrell-ashle...  The 5 Spot
# 13   $10  https://the5spot.club/event/tim-carroll-rocknr...  The 5 Spot
# 14   $10           https://the5spot.club/event/hoedown-vii/  The 5 Spot

# %%
spot_df.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\spot_df.csv")

# %% [markdown]
# # The End

# %%
end_URL = 'https://endnashville.com/events/'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'} 
end_response = requests.get(end_URL, headers=headers)
end_webpage = BS(end_response.content, 'lxml') 

end_narrow = end_webpage.find("div", attrs={"class":"tribe-events-loop vcalendar"})
end_urls = end_narrow.find_all("a", attrs={"class":"url"})

end_url_list = []
for url in end_urls:
    if url['href'] not in end_url_list:
        end_url_list.append(url['href'])
end_url_list

i = 0
end_events_list = []
for end_url in end_url_list:
    if end_url != None:
        end_dict = {}
        end_ticket_response = requests.get(end_url, headers=headers)
        end_ticket_webpage = BS(end_ticket_response.content, 'lxml')
        end_list_date = end_ticket_webpage.find('p', attrs= {"class":"rhino-event-date"})
        end_list_artist = end_ticket_webpage.find('a', attrs= {"class":"url"})
        end_list_time = end_ticket_webpage.find('p', attrs= {"class":"rhino-event-time"})
        end_list_price = end_ticket_webpage.find('p', attrs= {"class":"rhino-event-price"})
            
        if end_list_date != None:
            end_dict['event_date'] = end_list_date.text
        else:
            end_dict['event_date'] = "No Date Listed"
            
        if end_list_artist != None:
            end_dict['event_name'] = end_list_artist.text.strip()
        else:
            end_dict['event_name'] = "Artist Not Found"
            
        if end_list_time != None:
            end_dict['show_time'] = end_list_time.text
        else:
            end_dict['show_time'] = "Time Not Found"
        
        if end_list_price != None:
            end_dict['price'] = end_list_price.text.strip()
        else:
            end_dict['price'] = "Price Not Listed"
        end_dict['ticket_url'] = end_url
        end_events_list.append(end_dict)
        i += 1  
        if i == 21:
            break

# %%
end_df = pd.DataFrame.from_dict(end_events_list)
end_df['event_date'] = end_df.event_date.str.replace("(.*,)","")
end_df['show_time'] = end_df.show_time.str.replace("(Show :)","")
end_df['show_time'] = end_df.show_time.str.replace(" pm","")
end_df['Venue'] = 'The End'
end_df
# Out:
# <ipython-input-57-970b8cd33b3d>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   end_df['event_date'] = end_df.event_date.str.replace("(.*,)","")
# <ipython-input-57-970b8cd33b3d>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   end_df['show_time'] = end_df.show_time.str.replace("(Show :)","")
#    event_date                                         event_name show_time  \
# 0      Apr 22  Sensi Trails w/Rebel Shakedown, Bonzai, Plainv...      7:00
# 1      Apr 23                            Loving  w/ Sipper – 18+      8:00
# 2      Apr 25  “Dark Mattter Tour” RIVALS  w/Ashland & Josh L...      7:30
# 3      Apr 26   Summer League w/Bean & DJ Dominic Baglione – 18+      8:00
# 4      Apr 27  Joshua Quimby w/Liam St. John & Andrew Montana...      8:00
# 5      Apr 28     Ultra Q w/Benches , Blackpool Mecca – All Ages      8:00
# 6      Apr 29  Live Emo Cover Night: Feat. Ellie Stone w/The ...      8:00
# 7      Apr 30  *Cancelled* Mac Lethal w/Feral The Earthworm –...      8:00
# 8      Apr 30  Garden Of Eden w/Red Ransom & Hippies & Cowboy...      8:00
# 9       May 1  Exociety presents: The Out Of The Woods Tour f...      8:00
# 10      May 4  Sugar In The Gas Tank w/ Platinum Moon, Keep T...      8:00
# 11      May 5           Legacy Concerts Presents: Essenger – 18+      8:00
# 12      May 6                    Cam Cole w/ Volcano Girls – 18+      8:00
# 13      May 7  Lydia’s Castle EP Release w/ True Villains, Vo...      8:00
# 14     May 11  SOLD OUT: Legacy Concerts Presents: Peter McPo...      8:00
# 15     May 12   Felix Tandem w/Gentry Blue & Throw Pillows – 18+      8:00
# 16     May 13  Rivers Of Nihil w/Fallujah, Alluvial & Warforg...      7:00
# 17     May 14  Legit Smitty w/Elijah Johnston, Well Kept & Sa...      8:00
# 18     May 15  Spring Invasion feat. Leilani Kilgore, The Big...      6:00
# 19     May 18  Pepperwood w/Morgan Lee Powers & Luke Bandy – 18+      7:30
# 20     May 19  Weathers w/ Moontower, The Orphan The Poet- AL...      7:00
#
#                price                                         ticket_url  \
# 0                $20  https://endnashville.com/event/sensi-trails-w-...
# 1                $16  https://endnashville.com/event/loving-w-sipper...
# 2                $15  https://endnashville.com/event/dark-mattter-to...
# 3                 $8  https://endnashville.com/event/summer-league-w...
# 4                 $8  https://endnashville.com/event/joshua-quimby-w...
# 5                $14  https://endnashville.com/event/ultra-q-w-bench...
# 6                 $8  https://endnashville.com/event/live-emo-cover-...
# 7   Price Not Listed  https://endnashville.com/event/cancelled-mac-l...
# 8                 $8  https://endnashville.com/event/garden-of-eden-...
# 9                $15  https://endnashville.com/event/exociety-presen...
# 10                $8  https://endnashville.com/event/sugar-in-the-ga...
# 11               $13  https://endnashville.com/event/legacy-concerts...
# 12               $10  https://endnashville.com/event/cam-cole-w-volc...
# 13               $10  https://endnashville.com/event/lydias-castle-e...
# 14  Price Not Listed  https://endnashville.com/event/sold-out-legacy...
# 15                $8  https://endnashville.com/event/felix-tandem-w-...
# 16               $15  https://endnashville.com/event/rivers-of-nihil...
# 17                $8  https://endnashville.com/event/legit-smitty-w-...
# 18               $12  https://endnashville.com/event/spring-invasion...
# 19               $12  https://endnashville.com/event/pepperwood-w-mo...
# 20        $15 to $65  https://endnashville.com/event/weathers-w-moon...
#
#       Venue
# 0   The End
# 1   The End
# 2   The End
# 3   The End
# 4   The End
# 5   The End
# 6   The End
# 7   The End
# 8   The End
# 9   The End
# 10  The End
# 11  The End
# 12  The End
# 13  The End
# 14  The End
# 15  The End
# 16  The End
# 17  The End
# 18  The End
# 19  The End
# 20  The End

# %%
end_df.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\end_df.csv", index=False)

# %%
venues = [mmw_df, base_df, beast_df, mrcy_df, rymn_df, spot_df, end_df]

venues_df = pd.concat(venues)

# %%
venues_df.to_csv(r"C:\Users\jal32\Documents\NSS\Capstones\venues_df.csv", index=False)
